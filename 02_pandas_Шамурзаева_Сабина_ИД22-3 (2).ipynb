# %% [markdown]
# # Pandas

# %% [markdown]
# Материалы:
# * Макрушин С.В. "Лекция 2: Библиотека Pandas"
# * https://pandas.pydata.org/docs/user_guide/index.html#
# * https://pandas.pydata.org/docs/reference/index.html
# * Уэс Маккини. Python и анализ данных

# %% [markdown]
# ## Лабораторная работа №2

# %% [markdown]
# ### Базовые операции с `DataFrame`

# %% [markdown]
# 1.1 В файлах `recipes_sample.csv` и `reviews_sample.csv` находится информация об рецептах блюд и отзывах на эти рецепты соответственно. Загрузите данные из файлов в виде `pd.DataFrame` с названиями `recipes` и `reviews`. Обратите внимание на корректное считывание столбца с индексами в таблице `reviews` (безымянный столбец).

# %%
import numpy as np
import pandas as pd
recipies = pd.read_csv('recipes_sample.csv') 
recipies['submitted'] = pd.to_datetime(recipies['submitted']) # модификация по заданию 2.1
reviews = pd.read_csv('reviews_sample.csv') 
reviews = reviews.rename(columns={'Unnamed: 0': 'id'})
recipies
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# 2                1533 2002-08-29      NaN
# 3               22724 2002-07-27      NaN
# 4                4470 2004-02-23      4.0
# ...               ...        ...      ...
# 29995          200862 2007-11-25     16.0
# 29996          177443 2009-08-24      NaN
# 29997          161745 2004-11-03      NaN
# 29998          227978 2012-08-29      NaN
# 29999          506822 2008-04-15      9.0
#
#                                              description  n_ingredients
# 0      an original recipe created by chef scott meska...           18.0
# 1      my children and their friends ask for my homem...            NaN
# 2                these were so go, it surprised even me.            8.0
# 3      my sister-in-law made these for us at a family...            NaN
# 4      i think a fondue is a very romantic casual din...            NaN
# ...                                                  ...            ...
# 29995  this is based on a french recipe but i changed...           10.0
# 29996  this is a traditional fresh plum cake, thought...           11.0
# 29997  this is a traditional late summer early fall s...            NaN
# 29998  this is a delicious soup that i originally fou...            NaN
# 29999  i've heard of the 'cookies by design' company,...           10.0
#
# [30000 rows x 8 columns]

# %% [markdown]
# 1.2 Для каждой из таблиц выведите основные параметры:
# * количество точек данных (строк);
# * количество столбцов;
# * тип данных каждого столбца.

# %%
len_1 = len(recipies)
len_2 = len(reviews)
num_col_1 = len(recipies.columns)
num_col_2 = len(reviews.columns)
j = 0
j_1 = 0
print(f'Количество точек данных recipies: {len_1}, количество точек данных reviews: {len_2}')
print(f'Количество столбцов recipies: {num_col_1}, количество столбцов reviews: {num_col_2}')
for i in recipies.columns:
    print(f'Тип данных {j} столбца recipies: {recipies[i].dtype}')
    j+=1
for i in reviews.columns:
    print(f'Тип данных {j_1} столбца reviews: {reviews[i].dtype}')
    j_1+=1
# Out:
# Количество точек данных recipies: 30000, количество точек данных reviews: 126696
# Количество столбцов recipies: 8, количество столбцов reviews: 6
# Тип данных 0 столбца recipies: object
# Тип данных 1 столбца recipies: int64
# Тип данных 2 столбца recipies: int64
# Тип данных 3 столбца recipies: int64
# Тип данных 4 столбца recipies: datetime64[ns]
# Тип данных 5 столбца recipies: float64
# Тип данных 6 столбца recipies: object
# Тип данных 7 столбца recipies: float64
# Тип данных 0 столбца reviews: int64
# Тип данных 1 столбца reviews: int64
# Тип данных 2 столбца reviews: int64
# Тип данных 3 столбца reviews: object
# Тип данных 4 столбца reviews: int64
# Тип данных 5 столбца reviews: object

# %% [markdown]
# 1.3 Исследуйте, в каких столбцах таблиц содержатся пропуски. Посчитайте долю строк, содержащих пропуски, в отношении к общему количеству строк.

# %%
print('Для recipies:')
for i in recipies.columns:
    if recipies[i].isna().any():
        print(f'В {i} содержатся пропуски')
        print(f'Количество пропусков в {i} = {len(recipies[i].isna()[recipies[i].isna() == True])}')
        print(f'Доля пропусков в {i} = {1-((len(recipies[i]) - len(recipies[i].isna()[recipies[i].isna() == True]))/len(recipies[i]))}')
print('Для reviews:')
for i in reviews.columns:
    if reviews[i].isna().any():
        print(f'В {i} содержатся пропуски')
        print(f'Количество пропусков в {i} = {len(reviews[i].isna()[reviews[i].isna() == True])}')
        print(f'Доля пропусков в {i} = {1-((len(reviews[i]) - len(reviews[i].isna()[reviews[i].isna() == True]))/len(reviews[i]))}')
# Out:
# Для recipies:
# В n_steps содержатся пропуски
# Количество пропусков в n_steps = 11190
# Доля пропусков в n_steps = 0.373
# В description содержатся пропуски
# Количество пропусков в description = 623
# Доля пропусков в description = 0.02076666666666671
# В n_ingredients содержатся пропуски
# Количество пропусков в n_ingredients = 8880
# Доля пропусков в n_ingredients = 0.29600000000000004
# Для reviews:
# В review содержатся пропуски
# Количество пропусков в review = 17
# Доля пропусков в review = 0.00013417945317928393

# %% [markdown]
# 1.4 Рассчитайте среднее значение для каждого из числовых столбцов (где это имеет смысл).

# %%
print('Для recipies:')
for i in recipies.columns:
    if recipies[i].dtype == 'int64' or recipies[i].dtype == 'float64':
        print(f'Среднее значение столбца {i} = {np.mean(recipies[i])}')
print('Для reviews:')
for i in reviews.columns:
    if reviews[i].dtype == 'int64' or reviews[i].dtype == 'float64':
        print(f'Среднее значение столбца {i} = {np.mean(reviews[i])}')
# Out:
# Для recipies:
# Среднее значение столбца id = 221879.294
# Среднее значение столбца minutes = 123.35813333333333
# Среднее значение столбца contributor_id = 5635900.5728
# Среднее значение столбца n_steps = 9.805582137161085
# Среднее значение столбца n_ingredients = 9.008285984848484
# Для reviews:
# Среднее значение столбца id = 566089.8211466818
# Среднее значение столбца user_id = 140801264.7374108
# Среднее значение столбца recipe_id = 160094.38706036497
# Среднее значение столбца rating = 4.410802235271832

# %% [markdown]
# 1.5 Создайте серию из 10 случайных названий рецептов.

# %%
rand_series = pd.Series(recipies['name'][np.random.randint(len(recipies['name']), size = (10))])
rand_series
# Out:
# 12558                                    greek lamb koftas
# 26194                         stuffed portabella mushrooms
# 19028    oktoberfest kraut  sausage spareribs and potatoes
# 4256                          butternut squash with pecans
# 3654                                           bread bowls
# 18794                                      noodle omelette
# 10144    easy peanut butter mousse pie with chocolate c...
# 24541                         slow cooker sausage stuffing
# 4741                         caribbean dump chicken   oamc
# 21612                             pudding   cream frosting
# Name: name, dtype: object

# %% [markdown]
# 1.6 Измените индекс в таблице `reviews`, пронумеровав строки, начиная с нуля.

# %%
reviews_chng = reviews.copy()
reviews_chng['id'] = np.arange(len(reviews['id']))
reviews_chng
# Out:
#             id     user_id  recipe_id        date  rating  \
# 0            0       21752      57993  2003-05-01       5
# 1            1      431813     142201  2007-09-16       5
# 2            2      400708     252013  2008-01-10       4
# 3            3  2001852463     404716  2017-12-11       5
# 4            4       95810     129396  2008-03-14       5
# ...        ...         ...        ...         ...     ...
# 126691  126691     1270706     335534  2009-05-17       4
# 126692  126692     2282344       8701  2012-06-03       0
# 126693  126693      689540     222001  2008-04-08       5
# 126694  126694  2000242659     354979  2015-06-02       5
# 126695  126695      463435     415599  2010-09-30       5
#
#                                                    review
# 0       Last week whole sides of frozen salmon fillet ...
# 1       So simple and so tasty!  I used a yellow capsi...
# 2       Very nice breakfast HH, easy to make and yummy...
# 3       These are a favorite for the holidays and so e...
# 4       Excellent soup!  The tomato flavor is just gre...
# ...                                                   ...
# 126691  This recipe was great! I made it last night. I...
# 126692  This recipe is outstanding. I followed the rec...
# 126693  Well, we were not a crowd but it was a fabulou...
# 126694  I have been a steak eater and dedicated BBQ gr...
# 126695  Wonderful and simple to prepare seasoning blen...
#
# [126696 rows x 6 columns]

# %% [markdown]
# 1.7 Выведите информацию о рецептах, время выполнения которых не больше 20 минут и кол-во ингредиентов в которых не больше 5.

# %%
mask_1 = (recipies['minutes'] <= 20) & (recipies['n_ingredients'] <= 5)
table_1 = recipies[mask_1]
table_1
# Out:
#                                                     name      id  minutes  \
# 28                                   quick biscuit bread  302399       20
# 60                         peas  fit for a king or queen  303944       20
# 90                     hawaiian sunrise           mimosa  100837        5
# 91            tasty dish s   banana pudding in 2 minutes  286484        2
# 94                                    1 minute meatballs   11361       13
# ...                                                  ...     ...      ...
# 29873  zip and steam red potatoes with butter and garlic  304922       13
# 29874                          ziplock vanilla ice cream   74250       10
# 29905                      zucchini and corn with cheese  256177       15
# 29980               zucchini with jalapeno monterey jack  320622       10
# 29983                          zucchini with serrano ham  162411       15
#
#        contributor_id  submitted  n_steps  \
# 28             213909 2008-05-06     11.0
# 60             213909 2008-05-16      NaN
# 90              58104 2004-09-29      4.0
# 91              47892 2008-02-13      NaN
# 94               4470 2001-09-03      NaN
# ...               ...        ...      ...
# 29873          724218 2008-05-27      9.0
# 29874           24386 2003-10-29      8.0
# 29905          305531 2007-09-29      4.0
# 29980          305531 2008-08-20      3.0
# 29983          152500 2006-03-31      6.0
#
#                                              description  n_ingredients
# 28     this is a wonderful quick bread to make as an ...            5.0
# 60     this recipe is so simple and the flavors are s...            5.0
# 90     pineapple mimosa was changed to hawaiian sunri...            3.0
# 91     "mmmm, i love bananas!" a --tasty dish-- origi...            4.0
# 94     this is a real short cut for cooks in a hurry....            2.0
# ...                                                  ...            ...
# 29873  i haven't tried this yet, but i am going to so...            5.0
# 29874  a fun thing for kids to do. may want to use mi...            3.0
# 29905  from betty crocker fresh spring recipes. i lik...            5.0
# 29980                                  simple and yummy!            3.0
# 29983  this dish is from tim malzer, a german chef wh...            5.0
#
# [2019 rows x 8 columns]

# %% [markdown]
# ### Работа с датами в `pandas`

# %% [markdown]
# 2.1 Преобразуйте столбец `submitted` из таблицы `recipes` в формат времени. Модифицируйте решение задачи 1.1 так, чтобы считать столбец сразу в нужном формате.

# %%
recipies['submitted'] = pd.to_datetime(recipies.submitted)
recipies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            30000 non-null  object
#  1   id              30000 non-null  int64
#  2   minutes         30000 non-null  int64
#  3   contributor_id  30000 non-null  int64
#  4   submitted       30000 non-null  datetime64[ns]
#  5   n_steps         18810 non-null  float64
#  6   description     29377 non-null  object
#  7   n_ingredients   21120 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(2)
# memory usage: 1.8+ MB

# %% [markdown]
# 2.2 Выведите информацию о рецептах, добавленных в датасет не позже 2010 года.

# %%
recipies[pd.DatetimeIndex(recipies['submitted']).year<=2010]
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29993                     zuni caf zucchini pickles  316950     2895
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# 2                1533 2002-08-29      NaN
# 3               22724 2002-07-27      NaN
# 4                4470 2004-02-23      4.0
# ...               ...        ...      ...
# 29993           62264 2008-07-31      NaN
# 29995          200862 2007-11-25     16.0
# 29996          177443 2009-08-24      NaN
# 29997          161745 2004-11-03      NaN
# 29999          506822 2008-04-15      9.0
#
#                                              description  n_ingredients
# 0      an original recipe created by chef scott meska...           18.0
# 1      my children and their friends ask for my homem...            NaN
# 2                these were so go, it surprised even me.            8.0
# 3      my sister-in-law made these for us at a family...            NaN
# 4      i think a fondue is a very romantic casual din...            NaN
# ...                                                  ...            ...
# 29993  refrigerator pickles for some of the zucchini ...            8.0
# 29995  this is based on a french recipe but i changed...           10.0
# 29996  this is a traditional fresh plum cake, thought...           11.0
# 29997  this is a traditional late summer early fall s...            NaN
# 29999  i've heard of the 'cookies by design' company,...           10.0
#
# [27661 rows x 8 columns]

# %% [markdown]
# ### Работа со строковыми данными в `pandas`

# %% [markdown]
# 3.1  Добавьте в таблицу `recipes` столбец `description_length`, в котором хранится длина описания рецепта из столбца `description`.

# %%
recipies['description_length']  = recipies['description'].str.len()
recipies[500:550]
# Out:
#                                                   name      id  minutes  \
# 500                          almond butterscotch latte  314777        5
# 501                                        almond cake  490199       50
# 502                          almond chicken appetizers  143938       35
# 503                               almond cloud cookies  335824       40
# 504                                 almond coconut joy  316673       10
# 505                  almond coffee cheesecake for anna  359713      170
# 506                          almond coffee creamer mix  198585        5
# 507                                     almond cookies  204147       58
# 508                          almond cream cheese glaze  211370       10
# 509                               almond crowned kugel   14613       80
# 510                    almond crusted cherry cream pie  265955       90
# 511                     almond crusted chicken breasts   22337       35
# 512  almond crusted pork with honey dijon dipping s...  386614       28
# 513  almond crusted tilapia with caramelized onions...  487671       55
# 514                       almond filled crescent rolls  179011       42
# 515                                  almond filo snake  502995       70
# 516                                     almond fingers   47545       30
# 517                        almond flour stevia cookies  519547       28
# 518                            almond green bean salad  335876       15
# 519                                       almond horns  179210       37
# 520                       almond ice cream  dairy free  370018     1455
# 521                                    almond joy cake  412006       70
# 522                            almond joy drop cookies  136451       28
# 523                                   almond joy fudge   57757       15
# 524                                   almond joy latte  160133        5
# 525                                        almond kiss  284868        5
# 526                                    almond kowadjik  456968       50
# 527                                       almond kulfi  136514      250
# 528                                  almond lemon cake  429293       60
# 529                               almond macaroon cake  213177       35
# 530                                   almond meltaways  339697       28
# 531                                       almond mocha  247025        5
# 532                                       almond paste   15869       15
# 533                           almond paste or marzipan   14149       35
# 534                          almond peach yogurt bread   80474       65
# 535                       almond poppy seed pound cake  401584      100
# 536                                     almond pudding  482653       95
# 537                                       almond puffs   41990      140
# 538                             almond raspberry torte   26809       80
# 539                         almond rhubarb coffee cake  118667       63
# 540                              almond rice casserole  183118       75
# 541                   almond rice custard with berries  115721       25
# 542                                almond roca cookies  148060       52
# 543                        almond roca gourmet popcorn  407545       20
# 544                                  almond shortbread  201417       22
# 545  almond sponge cake    spain bizcocho de almendras  370125       45
# 546                          almond stuffed tofu cubes   15458       45
# 547                               almond toffee crunch  403878       25
# 548                             almond toffee rugelach  402687       30
# 549                            almond truffle brownies  160310       35
#
#      contributor_id  submitted  n_steps  \
# 500          305531 2008-07-20      3.0
# 501         1706426 2012-11-13      NaN
# 502          125640 2005-11-07      NaN
# 503          224921 2008-11-08     10.0
# 504          157425 2008-07-30      NaN
# 505          128473 2009-03-08     20.0
# 506           69474 2006-11-30      NaN
# 507          317696 2007-01-08     10.0
# 508           58104 2007-02-13      2.0
# 509           21752 2001-11-20      7.0
# 510          463498 2007-11-15      7.0
# 511            1533 2002-03-14      NaN
# 512          347233 2009-08-24     10.0
# 513         2198343 2012-09-27      NaN
# 514          232669 2006-07-24      NaN
# 515         1925885 2013-07-04     17.0
# 516           58104 2002-11-24     12.0
# 517         1489145 2014-11-17      6.0
# 518           92006 2008-11-08      NaN
# 519          232669 2006-07-25     22.0
# 520          593927 2009-05-06      NaN
# 521         1020526 2010-02-07      NaN
# 522           24386 2005-09-06      NaN
# 523           24386 2003-04-03      NaN
# 524            8688 2006-03-15      2.0
# 525          327115 2008-02-07      NaN
# 526          482376 2011-05-22      NaN
# 527          151325 2005-09-07      7.0
# 528          527607 2010-06-10     16.0
# 529          454328 2007-02-22      NaN
# 530          166642 2008-11-27     14.0
# 531          327115 2007-08-17      4.0
# 532            4470 2001-12-16      5.0
# 533           10216 2001-11-13      NaN
# 534           10113 2004-01-08      NaN
# 535         1463218 2009-11-28     12.0
# 536          226863 2012-07-08      NaN
# 537           37305 2002-10-02      9.0
# 538           25455 2002-04-29     25.0
# 539            1535 2005-04-22     10.0
# 540          290499 2006-08-25      9.0
# 541           83400 2005-04-07     12.0
# 542           37449 2005-12-12     16.0
# 543          118840 2010-01-09      NaN
# 544          235456 2006-12-21     17.0
# 545          491979 2009-05-06      NaN
# 546           13063 2001-12-07      8.0
# 547         1427607 2009-12-15     15.0
# 548            6836 2009-12-07     20.0
# 549            4439 2006-03-16     19.0
#
#                                            description  n_ingredients  \
# 500  this is from the cookbook cappuccino espresso ...            5.0
# 501     slightly dense, intensely almond flavored cake            9.0
# 502  delicious, crispy chicken nuggets breaded with...            NaN
# 503  this is a recipe for one of king arthur flour'...            6.0
# 504  a frozen non-alcoholic drink your family will ...            NaN
# 505  this is the perfect choice for a elegant dinne...            NaN
# 506                                             yummy!            NaN
# 507  more italian goodies.  passive cook time is pe...           10.0
# 508  this is great on spice cake, carrot cake, bana...            4.0
# 509  my mother used to make this for very special d...           13.0
# 510  this is my dad's favorite pie. it's pretty eas...            NaN
# 511                                                NaN            NaN
# 512  this recipe is one i found on epicurious. it i...           10.0
# 513  ready, set, cook!  reynolds wrap contest entry...            NaN
# 514  these crescents are easy to prepare and it loo...            7.0
# 515  sweet and crunchy - and looks great on the pla...            NaN
# 516  a christmas must!!!!! these really need to be ...            9.0
# 517  this is a basic cookie made with real whole fo...            6.0
# 518              from a california almonds are in! ad.            8.0
# 519  we were eating some almond horns the other eve...            6.0
# 520                              zwt7 pacific islands.            5.0
# 521  what a great idea to make with a cake mix, and...            NaN
# 522  if you like the candy bar, you will love these...            NaN
# 523  no candy thermometer needed for this quick to ...            4.0
# 524  almond joy candy bar fans will enjoy this warm...            NaN
# 525                         yummy nutty hot chocolate.            2.0
# 526  this is an african adaption of a dessert made ...            9.0
# 527  this is a simplified and much quicker way of m...            NaN
# 528  delicious and reasonably low cal, i use splend...           13.0
# 529  this is a simple recipe that produces results ...            6.0
# 530  these little gems will melt in your mouth! rec...            5.0
# 531  this is wonderful on cool nights.  you could a...            NaN
# 532  making almond paste is so simple and to me it ...            3.0
# 533  marzipan, cover cakes with it, make biscuits w...            9.0
# 534  this is a recipe that i found at a bed and bre...           10.0
# 535  this recipe is very moist and tastes very good...           10.0
# 536  this is a milk pudding that is served in india...            8.0
# 537  this is an interesting change of pace if you l...            8.0
# 538  this cake is a "cover girl"--its picture was o...           12.0
# 539  from my collection of recipes. haven't tried i...           12.0
# 540                    vegetarian cooking for dummies.            NaN
# 541  this creamy rice pudding is yummy, very easy t...            NaN
# 542  this recipe came from lynn scully, rancho sant...           12.0
# 543                movie night treat from copykat.com.            9.0
# 544  i love to have this delicious cookie at christ...            7.0
# 545                                     posted for zwt            NaN
# 546  even tofu 'haters' will be intrigued by these ...            NaN
# 547  this recipe came from a book of wonderful reci...            5.0
# 548  this is a recipe i came up with on a whim whil...            6.0
# 549  this is from t.o.h. web site and starts with a...           12.0
#
#      description_length
# 500                98.0
# 501                46.0
# 502               162.0
# 503               129.0
# 504               143.0
# 505               174.0
# 506                 6.0
# 507               210.0
# 508               201.0
# 509               266.0
# 510               459.0
# 511                 NaN
# 512               487.0
# 513               193.0
# 514               124.0
# 515               216.0
# 516               211.0
# 517               264.0
# 518                37.0
# 519               316.0
# 520                21.0
# 521               168.0
# 522               127.0
# 523               157.0
# 524                63.0
# 525                26.0
# 526               103.0
# 527               493.0
# 528               112.0
# 529               282.0
# 530               140.0
# 531               147.0
# 532                81.0
# 533               199.0
# 534                88.0
# 535               146.0
# 536               407.0
# 537                95.0
# 538               386.0
# 539                52.0
# 540                31.0
# 541               445.0
# 542               121.0
# 543                35.0
# 544               203.0
# 545                14.0
# 546                74.0
# 547               260.0
# 548               279.0
# 549               169.0

# %% [markdown]
# 3.2 Измените название каждого рецепта в таблице `recipes` таким образом, чтобы каждое слово в названии начиналось с прописной буквы.

# %%
recipies['name']  = recipies['name'].str.title()
recipies
# Out:
#                                                name      id  minutes  \
# 0             George S At The Cove  Black Bean Soup   44123       90
# 1                Healthy For Them  Yogurt Popsicles   67664       10
# 2                      I Can T Believe It S Spinach   38798       30
# 3                              Italian  Gut Busters   35173       45
# 4          Love Is In The Air  Beef Fondue   Sauces   84797       25
# ...                                             ...     ...      ...
# 29995  Zurie S Holey Rustic Olive And Cheddar Bread  267661       80
# 29996          Zwetschgenkuchen  Bavarian Plum Cake  386977      240
# 29997   Zwiebelkuchen   Southwest German Onion Cake  103312       75
# 29998                                   Zydeco Soup  486161       60
# 29999        Cookies By Design   Cookies On A Stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# 2                1533 2002-08-29      NaN
# 3               22724 2002-07-27      NaN
# 4                4470 2004-02-23      4.0
# ...               ...        ...      ...
# 29995          200862 2007-11-25     16.0
# 29996          177443 2009-08-24      NaN
# 29997          161745 2004-11-03      NaN
# 29998          227978 2012-08-29      NaN
# 29999          506822 2008-04-15      9.0
#
#                                              description  n_ingredients  \
# 0      an original recipe created by chef scott meska...           18.0
# 1      my children and their friends ask for my homem...            NaN
# 2                these were so go, it surprised even me.            8.0
# 3      my sister-in-law made these for us at a family...            NaN
# 4      i think a fondue is a very romantic casual din...            NaN
# ...                                                  ...            ...
# 29995  this is based on a french recipe but i changed...           10.0
# 29996  this is a traditional fresh plum cake, thought...           11.0
# 29997  this is a traditional late summer early fall s...            NaN
# 29998  this is a delicious soup that i originally fou...            NaN
# 29999  i've heard of the 'cookies by design' company,...           10.0
#
#        description_length
# 0                   330.0
# 1                   255.0
# 2                    39.0
# 3                   154.0
# 4                   587.0
# ...                   ...
# 29995               484.0
# 29996               286.0
# 29997               311.0
# 29998               648.0
# 29999               125.0
#
# [30000 rows x 9 columns]

# %% [markdown]
# 3.3 Добавьте в таблицу `recipes` столбец `name_word_count`, в котором хранится количество слов из названии рецепта (считайте, что слова в названии разделяются только пробелами). Обратите внимание, что между словами может располагаться несколько пробелов подряд.

# %%
recipies['name_word_count']=(recipies['name']).str.split().str.len()
recipies.to_csv('3_3_pandas.csv')
recipies
# Out:
#                                                name      id  minutes  \
# 0             George S At The Cove  Black Bean Soup   44123       90
# 1                Healthy For Them  Yogurt Popsicles   67664       10
# 2                      I Can T Believe It S Spinach   38798       30
# 3                              Italian  Gut Busters   35173       45
# 4          Love Is In The Air  Beef Fondue   Sauces   84797       25
# ...                                             ...     ...      ...
# 29995  Zurie S Holey Rustic Olive And Cheddar Bread  267661       80
# 29996          Zwetschgenkuchen  Bavarian Plum Cake  386977      240
# 29997   Zwiebelkuchen   Southwest German Onion Cake  103312       75
# 29998                                   Zydeco Soup  486161       60
# 29999        Cookies By Design   Cookies On A Stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# 2                1533 2002-08-29      NaN
# 3               22724 2002-07-27      NaN
# 4                4470 2004-02-23      4.0
# ...               ...        ...      ...
# 29995          200862 2007-11-25     16.0
# 29996          177443 2009-08-24      NaN
# 29997          161745 2004-11-03      NaN
# 29998          227978 2012-08-29      NaN
# 29999          506822 2008-04-15      9.0
#
#                                              description  n_ingredients  \
# 0      an original recipe created by chef scott meska...           18.0
# 1      my children and their friends ask for my homem...            NaN
# 2                these were so go, it surprised even me.            8.0
# 3      my sister-in-law made these for us at a family...            NaN
# 4      i think a fondue is a very romantic casual din...            NaN
# ...                                                  ...            ...
# 29995  this is based on a french recipe but i changed...           10.0
# 29996  this is a traditional fresh plum cake, thought...           11.0
# 29997  this is a traditional late summer early fall s...            NaN
# 29998  this is a delicious soup that i originally fou...            NaN
# 29999  i've heard of the 'cookies by design' company,...           10.0
#
#        description_length  name_word_count
# 0                   330.0                8
# 1                   255.0                5
# 2                    39.0                7
# 3                   154.0                3
# 4                   587.0                8
# ...                   ...              ...
# 29995               484.0                8
# 29996               286.0                4
# 29997               311.0                5
# 29998               648.0                2
# 29999               125.0                7
#
# [30000 rows x 10 columns]

# %% [markdown]
# ### Группировки таблиц `pd.DataFrame`

# %% [markdown]
# 4.1 Посчитайте количество рецептов, представленных каждым из участников (`contributor_id`). Какой участник добавил максимальное кол-во рецептов?

# %%
file4_1=pd.DataFrame(recipies['contributor_id'].value_counts())
s=pd.DataFrame(file4_1)
print(f'{s}\n\n{s.iloc[0].name}\n')
# Out:
#          contributor_id
# 89831               421
# 37449               346
# 37779               345
# 1533                186
# 169430              183
# ...                 ...
# 1061628               1
# 1076183               1
# 429061                1
# 64032                 1
# 186118                1
#
# [8404 rows x 1 columns]
#
# 89831

# %% [markdown]
# 4.2 Посчитайте средний рейтинг к каждому из рецептов. Для скольких рецептов отсутствуют отзывы? Обратите внимание, что отзыв с нулевым рейтингом или не заполненным текстовым описанием не считается отсутствующим.

# %%
file4_2=pd.DataFrame(reviews['recipe_id'].value_counts())
file4_2
# Out:
#         recipe_id
# 27208        1382
# 82102         708
# 135350        674
# 107786        592
# 50719         486
# ...           ...
# 23964           1
# 499966          1
# 418761          1
# 430164          1
# 296868          1
#
# [28100 rows x 1 columns]

# %% [markdown]
# 4.3 Посчитайте количество рецептов с разбивкой по годам создания.

# %%
d4_3=pd.DatetimeIndex(recipies['submitted']).year
d4_3=pd.Series(d4_3)
d4_3.value_counts()
# Out:
# 2007    4429
# 2008    4029
# 2006    3473
# 2005    3130
# 2009    2963
# 2002    2644
# 2003    2334
# 2004    2153
# 2010    1538
# 2011     922
# 2012     659
# 2001     589
# 2013     490
# 1999     275
# 2014     139
# 2000     104
# 2015      42
# 2017      39
# 2016      24
# 2018      24
# Name: submitted, dtype: int64

# %% [markdown]
# ### Объединение таблиц `pd.DataFrame`

# %% [markdown]
# 5.1 При помощи объединения таблиц, создайте `DataFrame`, состоящий из четырех столбцов: `id`, `name`, `user_id`, `rating`. Рецепты, на которые не оставлен ни один отзыв, должны отсутствовать в полученной таблице. Подтвердите правильность работы вашего кода, выбрав рецепт, не имеющий отзывов, и попытавшись найти строку, соответствующую этому рецепту, в полученном `DataFrame`.

# %%
reviews['id']=reviews['recipe_id']
df5_1 = pd.merge(recipies, reviews) 
df5_1=df5_1[['id','name','user_id','rating']]
df5_1
# Out:
#             id                                    name  user_id  rating
# 0        44123   George S At The Cove  Black Bean Soup   743566       5
# 1        44123   George S At The Cove  Black Bean Soup    76503       5
# 2        44123   George S At The Cove  Black Bean Soup    34206       5
# 3        67664      Healthy For Them  Yogurt Popsicles   494084       5
# 4        67664      Healthy For Them  Yogurt Popsicles   303445       5
# ...        ...                                     ...      ...     ...
# 126691  486161                             Zydeco Soup   305531       5
# 126692  486161                             Zydeco Soup  1271506       5
# 126693  486161                             Zydeco Soup   724631       5
# 126694  486161                             Zydeco Soup   133174       5
# 126695  298512  Cookies By Design   Cookies On A Stick   804234       1
#
# [126696 rows x 4 columns]

# %% [markdown]
# 5.2 При помощи объединения таблиц и группировок, создайте `DataFrame`, состоящий из трех столбцов: `recipe_id`, `name`, `review_count`, где столбец `review_count` содержит кол-во отзывов, оставленных на рецепт `recipe_id`. У рецептов, на которые не оставлен ни один отзыв, в столбце `review_count` должен быть указан 0. Подтвердите правильность работы вашего кода, выбрав рецепт, не имеющий отзывов, и найдя строку, соответствующую этому рецепту, в полученном `DataFrame`.

# %%
a=pd.DataFrame(reviews['recipe_id'].value_counts())
a['id']=a.index
a.index=[[i for i in range(a.shape[0])]]
a.columns = ['review_count','id']
df5_2=pd.merge(a,reviews)
df5_2=pd.merge(df5_2,recipies)
df5_2=df5_2[['recipe_id', 'name', 'review_count']]
recipies['recipe_id']=recipies['id']
s2=pd.merge(recipies,reviews,how='outer')
s2=s2[s2['rating'].isna()]
df5_2=pd.merge(df5_2,s2,how='outer')
df5_2=df5_2[['review_count', 'name', 'recipe_id']]
df5_2['review_count']=df5_2['review_count'].fillna(0)
df5_2
# Out:
#         review_count                                  name  recipe_id
# 0             1382.0            To Die For Crock Pot Roast      27208
# 1             1382.0            To Die For Crock Pot Roast      27208
# 2             1382.0            To Die For Crock Pot Roast      27208
# 3             1382.0            To Die For Crock Pot Roast      27208
# 4             1382.0            To Die For Crock Pot Roast      27208
# ...              ...                                   ...        ...
# 128591           0.0                    Zingy Potato Salad      66966
# 128592           0.0    Zucchini  Mock Green Papaya  Salad     249846
# 128593           0.0         Zucchini And Corn With Cheese     256177
# 128594           0.0                    Zucchini Nut Salad     178243
# 128595           0.0  Zucchini With Bell Pepper And Tomato     363362
#
# [128596 rows x 3 columns]

# %% [markdown]
# 5.3. Выясните, рецепты, добавленные в каком году, имеют наименьший средний рейтинг?

# %%
reviews[reviews['id']==66]['rating'].sum()
# Out:
# 89

# %%
m=reviews.groupby(['id']).sum()
recipies['year']=pd.DatetimeIndex(recipies['submitted']).year
n=recipies[['id','year']]
m['id']=m.index
m.index=np.arange(m.shape[0])
df5_3=pd.merge(m,n)
rating_sum=df5_3.groupby(['year']).sum()
year_count=df5_3.groupby(['year']).count()
answer=rating_sum['rating']/year_count['id']
answer.sort_values()[:1]
# Out:
# year
# 2017    3.666667
# dtype: float64

# %% [markdown]
# ### Сохранение таблиц `pd.DataFrame`

# %% [markdown]
# 6.1 Отсортируйте таблицу в порядке убывания величины столбца `name_word_count` и сохраните результаты выполнения заданий 3.1-3.3 в csv файл.

# %%
recipies6_1=recipies.sort_values('name_word_count',ascending=False)
recipies6_1
# Out:
#                                                     name      id  minutes  \
# 26223  Subru Uncle S Whole Green Moong Dal I Ll Be Ma...   77188       95
# 28083  Tsr Version Of T G I  Friday S Black Bean Soup...  102274       75
# 26222  Subru Uncle S Toor Ki Dal Sindhi Style  Dad  M...   76908       65
# 27876  Top Secret Recipes Version Of  I H O P  Griddl...  113346       20
# 5734   Chicken Curry Or  Cat S Vomit On A Bed Of Magg...  294898       30
# ...                                                  ...     ...      ...
# 3253                                          Blackmoons  323195      430
# 4138                                         Bushwhacker  156521       10
# 2357                                            Basbousa   12957       60
# 15052                                          Josefinas  264859       20
# 4710                                            Caramels  143615       30
#
#        contributor_id  submitted  n_steps  \
# 26223            6357 2003-11-21      NaN
# 28083           74652 2004-10-19      9.0
# 26222            6357 2003-11-18     29.0
# 27876          175727 2005-03-14      5.0
# 5734           802799 2008-03-28     11.0
# ...               ...        ...      ...
# 3253           415934 2008-09-04      5.0
# 4138           177392 2006-02-17      1.0
# 2357            18391 2001-10-20      NaN
# 15052          498271 2007-11-11      7.0
# 4710           212088 2005-11-02      NaN
#
#                                              description  n_ingredients  \
# 26223  my dad and mom quite enjoy this lentil curry. ...           15.0
# 28083  from www.topsecretrecipes.com i got this copyc...           16.0
# 26222  this is the lentil curry that subru uncle(our ...           15.0
# 27876  this recipe is top secret recipes version of i...            9.0
# 5734   an old family recipe that's easy to make since...           12.0
# ...                                                  ...            ...
# 3253   my mom was a newlywed in the 1950s when she fo...            NaN
# 4138   this drink is an excellent after dinner drink ...            6.0
# 2357   this is a traditional middle eastern dessert. ...            NaN
# 15052  from the junior league of corpus christi tx, t...            NaN
# 4710   i've been making these at christmas time for y...            6.0
#
#        description_length  name_word_count  recipe_id  year
# 26223               343.0               15      77188  2003
# 28083               436.0               14     102274  2004
# 26222              1087.0               14      76908  2003
# 27876               129.0               14     113346  2005
# 5734                144.0               13     294898  2008
# ...                   ...              ...        ...   ...
# 3253                389.0                1     323195  2008
# 4138                124.0                1     156521  2006
# 2357                 78.0                1      12957  2001
# 15052                92.0                1     264859  2007
# 4710                341.0                1     143615  2005
#
# [30000 rows x 12 columns]

# %% [markdown]
# 6.2 Воспользовавшись `pd.ExcelWriter`, cохраните результаты 5.1 и 5.2 в файл: на лист с названием `Рецепты с оценками` сохраните результаты выполнения 5.1; на лист с названием `Количество отзывов по рецептам` сохраните результаты выполнения 5.2.

# %%
with pd.ExcelWriter(esults_5_1_2.xlsx",engine='xlsxwriter') as writer:
    s5_2.to_excel(writer, "Количество отзывов по рецептам")
    s5_1.to_excel(writer, sheet_name="Рецепты с оценками")
# Out:
#   Input In [50]
#     with pd.ExcelWriter(esults_5_1_2.xlsx",engine='xlsxwriter') as writer:
#                                                                           ^
# SyntaxError: EOL while scanning string literal

# %% [markdown]
# #### [версия 2]
# * Уточнены формулировки задач 1.1, 3.3, 4.2, 5.1, 5.2, 5.3
